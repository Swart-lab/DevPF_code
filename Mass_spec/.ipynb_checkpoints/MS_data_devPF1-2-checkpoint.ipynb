# %% [markdown]
# ### Aim
# Create scatterplots (volcano/MA-plots) for the mass spectrometry data for DevPF1-HA and DevPF2-GFP pulldown

# %%
# import packages
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe

plt.rcParams["font.family"] = "Arial"

# %%
input1 = ['input_files/Limma_results_DevPF1.csv.gz','input_files/Limma_results_DevPF2.csv.gz']

dPF1 = pd.read_csv(input1[0], compression = 'gzip', sep=",")
dPF2 = pd.read_csv(input1[1], compression = 'gzip', sep=",")

input2 = ['input_files/P2854_TMT16plex_5prc_psm_DevPF1.tsv.gz', 
          'input_files/P2854_TMT8plex_5prc_psm_DevPF2.tsv.gz']

dPF1_peptides = pd.read_csv(input2[0], compression = 'gzip', sep="\t")
dPF2_peptides = pd.read_csv(input2[1], compression = 'gzip', sep="\t")

# %%
dPF1['-log10(p)'] = np.log10(dPF1['pvalue']) * (-1)
dPF2['-log10(p)'] = np.log10(dPF2['pvalue']) * (-1)

# %%
list(dPF2_peptides)
# Out:
# ['Spectrum',
#  'Spectrum File',
#  'Peptide',
#  'Modified Peptide',
#  'Extended Peptide',
#  'Prev AA',
#  'Next AA',
#  'Peptide Length',
#  'Charge',
#  'Retention',
#  'Observed Mass',
#  'Calibrated Observed Mass',
#  'Observed M/Z',
#  'Calibrated Observed M/Z',
#  'Calculated Peptide Mass',
#  'Calculated M/Z',
#  'Delta Mass',
#  'Expectation',
#  'Hyperscore',
#  'Nextscore',
#  'PeptideProphet Probability',
#  'Number of Enzymatic Termini',
#  'Number of Missed Cleavages',
#  'Protein Start',
#  'Protein End',
#  'Intensity',
#  'Assigned Modifications',
#  'Observed Modifications',
#  'Purity',
#  'Is Unique',
#  'Protein',
#  'Protein ID',
#  'Entry Name',
#  'Gene',
#  'Protein Description',
#  'Mapped Genes',
#  'Mapped Proteins',
#  'Quan Usage',
#  'channel_126',
#  'channel_127N',
#  'channel_127C',
#  'channel_128N',
#  'channel_128C',
#  'channel_129N',
#  'channel_129C',
#  'channel_130N',
#  'channel_130C',
#  'channel_131N']

# %%
dPF2_peptides['Mapped Genes'] = dPF2_peptides['Mapped Genes'].str.contains('PTIWI10')
dPF2_peptides['Mapped Genes']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-bbb2f6f26b9b> in <module>
# ----> 1 dPF2_peptides['Mapped Genes'] = dPF2_peptides['Mapped Genes'].str.contains('PTIWI10')
#       2 dPF2_peptides['Mapped Genes']
#
# ~/miniconda3/envs/Jupyter/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# ~/miniconda3/envs/Jupyter/lib/python3.9/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~/miniconda3/envs/Jupyter/lib/python3.9/site-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     179         from pandas.core.arrays.string_ import StringDtype
#     180
# --> 181         self._inferred_dtype = self._validate(data)
#     182         self._is_categorical = is_categorical_dtype(data.dtype)
#     183         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~/miniconda3/envs/Jupyter/lib/python3.9/site-packages/pandas/core/strings/accessor.py in _validate(data)
#     233
#     234         if inferred_dtype not in allowed_types:
# --> 235             raise AttributeError("Can only use .str accessor with string values!")
#     236         return inferred_dtype
#     237
#
# AttributeError: Can only use .str accessor with string values!

# %%
# extract the gene names for genes of interest


# Sample input dictionary
input_dict = {
    "DevPF1": "GSPATT00009444001",
    "DevPF2": "GSPATT00019914001",
    "PTIWI10": "PTIWI10"
    # Add more keys and values as needed
}


result_dict = {}


for key, value in input_dict.items():
    # Search for the value in both "Gene" and "Mapped Genes" columns
    gene_matches = dPF2_peptides[dPF2_peptides["Gene"].eq(value)]
    
    #dPF2_peptides['Mapped Genes'] = dPF2_peptides['Mapped Genes'].str.split(', ', expand=True)
    #mapped_gene_matches = dPF2_peptides['Mapped Genes'].apply(lambda x: any(x.str.contains(value)))
    
    #mapped_gene_matches = dPF2_peptides[dPF2_peptides['Mapped Genes'].str.contains(value, regex=True)]
    
    pattern = fr'\b{value}\b'
    mapped_gene_matches = dPF2_peptides[dPF2_peptides['Mapped Genes'].str.contains(value, regex=True)]
    
    #mapped_gene_matches = dPF2_peptides[dPF2_peptides["Mapped Genes"].eq(value)]

    if not gene_matches.empty:
        result_dict[key] = gene_matches["Gene"].values[0]

    if not mapped_gene_matches.empty:
        result_dict[key] = mapped_gene_matches["Gene"].values[0]

print(result_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c7ea62158cd0> in <module>
#      24
#      25     pattern = fr'\b{value}\b'
# ---> 26     mapped_gene_matches = dPF2_peptides[dPF2_peptides['Mapped Genes'].str.contains(value, regex=True)]
#      27
#      28     #mapped_gene_matches = dPF2_peptides[dPF2_peptides["Mapped Genes"].eq(value)]
#
# ~/miniconda3/envs/Jupyter/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3795
#    3796         # Do we have a (boolean) 1d indexer?
# -> 3797         if com.is_bool_indexer(key):
#    3798             return self._getitem_bool_array(key)
#    3799
#
# ~/miniconda3/envs/Jupyter/lib/python3.9/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     133                     # Don't raise on e.g. ["A", "B", np.nan], see
#     134                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 135                     raise ValueError(na_msg)
#     136                 return False
#     137             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
dPF1
# Out:
#                    Gene Protein.ID  \
# 0     GSPATT00012163001     A0D0P4
# 1     GSPATT00022820001     A0E2Y1
# 2     GSPATT00026157001     A0EEU3
# 3     GSPATT00034469001     A0C2H4
# 4     GSPATT00030171001     A0BLX0
# ...                 ...        ...
# 3907  GSPATT00034717001     A0C372
# 3908  GSPATT00008605001     A0CMZ7
# 3909  GSPATT00035783001     A0C786
# 3910  GSPATT00033407001     A0BYD7
# 3911  GSPATT00001870001     A0D712
#
#                                     Protein.Description  \
# 0                          pyruvate, phosphate dikinase
# 1                       Isocitrate dehydrogenase [NADP]
# 2     Chromosome undetermined scaffold_92, whole gen...
# 3                                   valine--tRNA ligase
# 4                     Probable protein phosphatase 2C 2
# ...                                                 ...
# 3907  Chromosome undetermined scaffold_146, whole ge...
# 3908  Succinate dehydrogenase [ubiquinone] flavoprot...
# 3909  Chromosome undetermined scaffold_154, whole ge...
# 3910  Chromosome undetermined scaffold_137, whole ge...
# 3911  Chromosome undetermined scaffold_4, whole geno...
#
#                     Organism  found.in.files  \
# 0     Paramecium tetraurelia               1
# 1     Paramecium tetraurelia               1
# 2     Paramecium tetraurelia               1
# 3     Paramecium tetraurelia               1
# 4     Paramecium tetraurelia               1
# ...                      ...             ...
# 3907  Paramecium tetraurelia               1
# 3908  Paramecium tetraurelia               1
# 3909  Paramecium tetraurelia               1
# 3910  Paramecium tetraurelia               1
# 3911  Paramecium tetraurelia               1
#
#       found.in.file_P2854_TMT16plex_5prc_protein.tsv  found.in.conditions  \
# 0                                                  1                    4
# 1                                                  1                    4
# 2                                                  1                    4
# 3                                                  1                    4
# 4                                                  1                    4
# ...                                              ...                  ...
# 3907                                               1                    4
# 3908                                               1                    4
# 3909                                               1                    4
# 3910                                               1                    4
# 3911                                               1                    4
#
#       found.in.reps  max.Unique.Peptides  max.Razor.Peptides  ...  \
# 0                 4                    7                  30  ...
# 1                 4                    3                   9  ...
# 2                 4                    3                   3  ...
# 3                 4                   11                  12  ...
# 4                 4                    1                   5  ...
# ...             ...                  ...                 ...  ...
# 3907              4                    5                   9  ...
# 3908              4                    0                   6  ...
# 3909              4                    2                   2  ...
# 3910              4                    0                   4  ...
# 3911              4                    0                   4  ...
#
#       qval.fdrtool  lfdr.fdrtool                         comparison  \
# 0         1.000000           1.0                      PS17_E - WT_E
# 1         1.000000           1.0                      PS17_E - WT_E
# 2         1.000000           1.0                      PS17_E - WT_E
# 3         1.000000           1.0                      PS17_E - WT_E
# 4         1.000000           1.0                      PS17_E - WT_E
# ...            ...           ...                                ...
# 3907      0.981624           1.0  (PS17_L - PS17_E) - (WT_L - WT_E)
# 3908      0.981670           1.0  (PS17_L - PS17_E) - (WT_L - WT_E)
# 3909      0.981716           1.0  (PS17_L - PS17_E) - (WT_L - WT_E)
# 3910      0.981757           1.0  (PS17_L - PS17_E) - (WT_L - WT_E)
# 3911      0.981773           1.0  (PS17_L - PS17_E) - (WT_L - WT_E)
#
#       hit_annotation_method        pvalue           fdr    hit  \
# 0                     limma  7.983119e-12  2.813784e-09   True
# 1                     limma  8.631240e-12  2.813784e-09   True
# 2                     limma  1.555933e-11  2.991505e-09   True
# 3                     limma  2.657092e-11  2.991505e-09   True
# 4                     limma  2.687865e-11  2.991505e-09   True
# ...                     ...           ...           ...    ...
# 3907                  limma  9.786654e-01  9.847066e-01  False
# 3908                  limma  9.824515e-01  9.869928e-01  False
# 3909                  limma  9.863237e-01  9.893585e-01  False
# 3910                  limma  9.897828e-01  9.911315e-01  False
# 3911                  limma  9.911315e-01  9.911315e-01  False
#
#        hit_annotation  Total.Intensity  -log10(p)
# 0        enriched hit         49675232  11.097827
# 1        enriched hit          8598084  11.063927
# 2        enriched hit          2100262  10.808009
# 3        enriched hit         10319394  10.575593
# 4        enriched hit          7922405  10.570593
# ...               ...              ...        ...
# 3907  enriched no hit         23172334   0.009366
# 3908  enriched no hit          5329061   0.007689
# 3909  enriched no hit         31906091   0.005981
# 3910  enriched no hit         19838306   0.004460
# 3911  enriched no hit          4454605   0.003869
#
# [3912 rows x 28 columns]

# %%
type(groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
fig, ax = plt.subplots(figsize = (10,6))

groups = dPF2.groupby('hit_annotation')
#groups.reindex(['enriched hit', 'hit', 'enriched candidate', 'no hit'], level='hit_annotation')

colors = ['red', 'blue', 'orange', 'grey']
count = int(-1)
category = ['enriched hit', 'hit', 'enriched candidate', 'no hit']

for cat in category:
    count += 1
    for name, group in groups:
        if name == cat:
            ax.plot(group.logFC, group['-log10(p)'], marker='o', linestyle='', markersize=8, label=name,
            markeredgecolor='black', markerfacecolor = colors[count])

# label data poitns


ax.set_xlabel('log2(FoldChange)', wrap = True, fontsize = 20)
ax.set_ylabel('-log10(p-value)', wrap = True, fontsize = 20)
ax.set_xlim(-1.5,3.0)
ax.set_ylim(0,7.0)
ax.tick_params(axis='both', which='major', labelsize=16)
ax.axvline(x=0, ymin=0, ymax=7, ls='-', color='black', lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.80), fancybox=True, fontsize = 20);
fig.tight_layout()

# %%
# create sub-dataframes


comparisons = ['PS17_E - WT_E','PS17_L - WT_L','PS17_L - PS17_E','WT_L - WT_E',
               '(PS17_L - PS17_E) - (WT_L - WT_E)', '(PS17_L - WT_L) - (PS17_E - WT_E)']
counter = int(-1)
dfs = []

for c in comparisons:
    counter += 1
    df = dPF1.loc[dPF1['comparison']==comparisons[counter]]
    dfs.append(df)

# %%
dftest = dPF1.loc[dPF1['comparison'] == 'PS17_E - WT_E']
dftestb = dftest.loc[dPF1['hit_annotation'] == 'enriched hit']
dftestb
# Out:
#                   Gene Protein.ID  \
# 0    GSPATT00012163001     A0D0P4
# 1    GSPATT00022820001     A0E2Y1
# 2    GSPATT00026157001     A0EEU3
# 3    GSPATT00034469001     A0C2H4
# 4    GSPATT00030171001     A0BLX0
# ..                 ...        ...
# 576  GSPATT00013583001     A0D519
# 577  GSPATT00023584001     A0E540
# 579  GSPATT00033124001     A0BXK4
# 589  GSPATT00038399001     A0CHN0
# 591  GSPATT00001003001     A0CKH2
#
#                                    Protein.Description  \
# 0                         pyruvate, phosphate dikinase
# 1                      Isocitrate dehydrogenase [NADP]
# 2    Chromosome undetermined scaffold_92, whole gen...
# 3                                  valine--tRNA ligase
# 4                    Probable protein phosphatase 2C 2
# ..                                                 ...
# 576  Chromosome undetermined scaffold_38, whole gen...
# 577  Chromosome undetermined scaffold_79, whole gen...
# 579  Chromosome undetermined scaffold_134, whole ge...
# 589                        Protein disulfide-isomerase
# 591  Chromosome undetermined scaffold_2, whole geno...
#
#                    Organism  found.in.files  \
# 0    Paramecium tetraurelia               1
# 1    Paramecium tetraurelia               1
# 2    Paramecium tetraurelia               1
# 3    Paramecium tetraurelia               1
# 4    Paramecium tetraurelia               1
# ..                      ...             ...
# 576  Paramecium tetraurelia               1
# 577  Paramecium tetraurelia               1
# 579  Paramecium tetraurelia               1
# 589  Paramecium tetraurelia               1
# 591  Paramecium tetraurelia               1
#
#      found.in.file_P2854_TMT16plex_5prc_protein.tsv  found.in.conditions  \
# 0                                                 1                    4
# 1                                                 1                    4
# 2                                                 1                    4
# 3                                                 1                    4
# 4                                                 1                    4
# ..                                              ...                  ...
# 576                                               1                    4
# 577                                               1                    4
# 579                                               1                    4
# 589                                               1                    4
# 591                                               1                    4
#
#      found.in.reps  max.Unique.Peptides  max.Razor.Peptides  ...  \
# 0                4                    7                  30  ...
# 1                4                    3                   9  ...
# 2                4                    3                   3  ...
# 3                4                   11                  12  ...
# 4                4                    1                   5  ...
# ..             ...                  ...                 ...  ...
# 576              4                    1                   3  ...
# 577              4                    1                   6  ...
# 579              4                    1                   2  ...
# 589              4                   21                  21  ...
# 591              4                    2                   8  ...
#
#      qval.fdrtool  lfdr.fdrtool     comparison  hit_annotation_method  \
# 0             1.0           1.0  PS17_E - WT_E                  limma
# 1             1.0           1.0  PS17_E - WT_E                  limma
# 2             1.0           1.0  PS17_E - WT_E                  limma
# 3             1.0           1.0  PS17_E - WT_E                  limma
# 4             1.0           1.0  PS17_E - WT_E                  limma
# ..            ...           ...            ...                    ...
# 576           1.0           1.0  PS17_E - WT_E                  limma
# 577           1.0           1.0  PS17_E - WT_E                  limma
# 579           1.0           1.0  PS17_E - WT_E                  limma
# 589           1.0           1.0  PS17_E - WT_E                  limma
# 591           1.0           1.0  PS17_E - WT_E                  limma
#
#            pvalue           fdr   hit  hit_annotation  Total.Intensity  \
# 0    7.983119e-12  2.813784e-09  True    enriched hit         49675232
# 1    8.631240e-12  2.813784e-09  True    enriched hit          8598084
# 2    1.555933e-11  2.991505e-09  True    enriched hit          2100262
# 3    2.657092e-11  2.991505e-09  True    enriched hit         10319394
# 4    2.687865e-11  2.991505e-09  True    enriched hit          7922405
# ..            ...           ...   ...             ...              ...
# 576  1.507194e-02  1.703103e-02  True    enriched hit          2721434
# 577  1.535518e-02  1.732107e-02  True    enriched hit          2693293
# 579  1.858753e-02  2.089495e-02  True    enriched hit          2038436
# 589  3.916480e-02  4.328042e-02  True    enriched hit          6366478
# 591  4.416492e-02  4.864109e-02  True    enriched hit          4989484
#
#      -log10(p)
# 0    11.097827
# 1    11.063927
# 2    10.808009
# 3    10.575593
# 4    10.570593
# ..         ...
# 576   1.821831
# 577   1.813745
# 579   1.730778
# 589   1.407104
# 591   1.354923
#
# [567 rows x 28 columns]

# %%
dfs[5]
# Out:
#                    Gene Protein.ID  \
# 2608                T1F     Q27172
# 2609  GSPATT00012163001     A0D0P4
# 2610  GSPATT00023786001     A0E6Z1
# 2611  GSPATT00026157001     A0EEU3
# 2612  GSPATT00030171001     A0BLX0
# ...                 ...        ...
# 3255  GSPATT00034717001     A0C372
# 3256  GSPATT00008605001     A0CMZ7
# 3257  GSPATT00035783001     A0C786
# 3258  GSPATT00033407001     A0BYD7
# 3259  GSPATT00001870001     A0D712
#
#                                     Protein.Description  \
# 2608                     Trichocyst matrix protein T1-F
# 2609                       pyruvate, phosphate dikinase
# 2610  Chromosome undetermined scaffold_80, whole gen...
# 2611  Chromosome undetermined scaffold_92, whole gen...
# 2612                  Probable protein phosphatase 2C 2
# ...                                                 ...
# 3255  Chromosome undetermined scaffold_146, whole ge...
# 3256  Succinate dehydrogenase [ubiquinone] flavoprot...
# 3257  Chromosome undetermined scaffold_154, whole ge...
# 3258  Chromosome undetermined scaffold_137, whole ge...
# 3259  Chromosome undetermined scaffold_4, whole geno...
#
#                     Organism  found.in.files  \
# 2608  Paramecium tetraurelia               1
# 2609  Paramecium tetraurelia               1
# 2610  Paramecium tetraurelia               1
# 2611  Paramecium tetraurelia               1
# 2612  Paramecium tetraurelia               1
# ...                      ...             ...
# 3255  Paramecium tetraurelia               1
# 3256  Paramecium tetraurelia               1
# 3257  Paramecium tetraurelia               1
# 3258  Paramecium tetraurelia               1
# 3259  Paramecium tetraurelia               1
#
#       found.in.file_P2854_TMT16plex_5prc_protein.tsv  found.in.conditions  \
# 2608                                               1                    4
# 2609                                               1                    4
# 2610                                               1                    4
# 2611                                               1                    4
# 2612                                               1                    4
# ...                                              ...                  ...
# 3255                                               1                    4
# 3256                                               1                    4
# 3257                                               1                    4
# 3258                                               1                    4
# 3259                                               1                    4
#
#       found.in.reps  max.Unique.Peptides  max.Razor.Peptides  ...  \
# 2608              4                    0                   2  ...
# 2609              4                    7                  30  ...
# 2610              4                    4                   4  ...
# 2611              4                    3                   3  ...
# 2612              4                    1                   5  ...
# ...             ...                  ...                 ...  ...
# 3255              4                    5                   9  ...
# 3256              4                    0                   6  ...
# 3257              4                    2                   2  ...
# 3258              4                    0                   4  ...
# 3259              4                    0                   4  ...
#
#       qval.fdrtool  lfdr.fdrtool                         comparison  \
# 2608      0.000391      0.000391  (PS17_L - WT_L) - (PS17_E - WT_E)
# 2609      0.000391      0.002125  (PS17_L - WT_L) - (PS17_E - WT_E)
# 2610      0.000969      0.106279  (PS17_L - WT_L) - (PS17_E - WT_E)
# 2611      0.040364      0.106279  (PS17_L - WT_L) - (PS17_E - WT_E)
# 2612      0.053366      0.106279  (PS17_L - WT_L) - (PS17_E - WT_E)
# ...            ...           ...                                ...
# 3255      0.981624      1.000000  (PS17_L - WT_L) - (PS17_E - WT_E)
# 3256      0.981670      1.000000  (PS17_L - WT_L) - (PS17_E - WT_E)
# 3257      0.981716      1.000000  (PS17_L - WT_L) - (PS17_E - WT_E)
# 3258      0.981757      1.000000  (PS17_L - WT_L) - (PS17_E - WT_E)
# 3259      0.981773      1.000000  (PS17_L - WT_L) - (PS17_E - WT_E)
#
#       hit_annotation_method    pvalue       fdr    hit   hit_annotation  \
# 2608                  limma  0.000007  0.002384   True     enriched hit
# 2609                  limma  0.000005  0.002384   True     enriched hit
# 2610                  limma  0.000016  0.003369   True     enriched hit
# 2611                  limma  0.000099  0.015149   True     enriched hit
# 2612                  limma  0.000138  0.015149   True     enriched hit
# ...                     ...       ...       ...    ...              ...
# 3255                  limma  0.978665  0.984707  False  enriched no hit
# 3256                  limma  0.982451  0.986993  False  enriched no hit
# 3257                  limma  0.986324  0.989358  False  enriched no hit
# 3258                  limma  0.989783  0.991131  False  enriched no hit
# 3259                  limma  0.991131  0.991131  False  enriched no hit
#
#       Total.Intensity  -log10(p)
# 2608          5452193   5.135988
# 2609         49675232   5.260283
# 2610          7844160   4.809580
# 2611          2100262   4.004743
# 2612          7922405   3.858635
# ...               ...        ...
# 3255         23172334   0.009366
# 3256          5329061   0.007689
# 3257         31906091   0.005981
# 3258         19838306   0.004460
# 3259          4454605   0.003869
#
# [652 rows x 28 columns]

# %%
# volcano plots for the knockdown comparisons at each time point

fig, axes = plt.subplots(2, 3,figsize = (10,10))
ax1, ax2, ax3 = axes[0]
ax4, ax5, ax6 = axes[1]


ax = [ax1, ax2, ax3, ax4, ax5, ax6]

colors = ['violet', 'mediumpurple', 'skyblue', 'lightcyan','beige', 'white']
category = ['enriched hit', 'hit', 'enriched candidate', 'candidate', 'enriched no hit', 'no hit']
ax_count = int(-1)
x_max = []
x_min = []
y_max = []
num_sig = []

#groups = resPN100.groupby('significance')
for df in dfs:
    groups = df.groupby('hit_annotation')
    #num_sig.append(sig_count(df))
    x_max.append(max(df['logFC']))
    x_min.append(min(df['logFC']))
    y_max.append(max(df['-log10(p)']))
    ax_count += 1
    c_count = int(-1)
    for cat in category:
        c_count += 1
        for name, group in groups:
            if name == cat:
                ax[ax_count].plot(group.logFC, group['-log10(p)'], marker='o', linestyle='', 
                                     markersize=5, label=name, markeredgecolor='black', 
                                     markerfacecolor = colors[c_count], markeredgewidth = 0.5)
    ax[ax_count].plot(interest[ax_count]['logFC'], interest[ax_count]['-log10(p)'], marker='o', linestyle='', 
                                     markersize=5, label= 'interest', markeredgecolor='white', 
                                     markerfacecolor = 'black', markeredgewidth = 0.5)
    
ax_count = int(-1)
for a in ax:
    ax_count += 1
    a.set_xlim((x_min[ax_count] - 1), (x_max[ax_count] + 1))
    #a.set_ylim(0, (y_max[ax_count] + 1))
    a.set_ylim(0, 12)
    a.tick_params(axis='both', which='major', labelsize=15)
    a.axvline(x=0, ymin=0, ymax=7, ls='-', color='black', lw=1)
    #a.annotate(f"{num_sig[ax_count][0]}", xy = (0.81, 0.9),xycoords='axes fraction',fontsize=17)
    #a.annotate(f"{num_sig[ax_count][1]}", xy = (0.05, 0.9),xycoords='axes fraction',fontsize=17)
    
    # label data poitns
    a.annotate('PTIWI01/09', xy= (PTIWI19[ax_count]['logFC'], PTIWI19[ax_count]['-log10(p)']), textcoords='data')
    a.annotate('H4', xy= (H_4[ax_count]['logFC'], H_4[ax_count]['-log10(p)']), textcoords='data')
    #a.annotate('H2A', xy= (H_2A[ax_count]['logFC'], H_2A[ax_count]['-log10(p)']), textcoords='data')
    a.annotate('H2B', xy= (H_2B[ax_count]['logFC'], H_2B[ax_count]['-log10(p)']), textcoords='data')
    a.annotate('DevPF1/2', xy= (DevPF12[ax_count]['logFC'], DevPF12[ax_count]['-log10(p)']), textcoords='data')
    
    if ax_count > 2:
        a.set_xlabel('log2(FoldChange)', wrap = True, fontsize = 17)
    if ax_count == 0 or ax_count == 3:
        a.set_ylabel('-log10(padj)', wrap = True, fontsize = 17)



#set titles
ax1.set_title('early: DevPF1 - WT', wrap = True, fontsize = 15)
ax2.set_title('late: DevPF1 - WT', wrap = True, fontsize = 15)
ax3.set_title('DevPF1: late - early', wrap = True, fontsize = 15)
ax4.set_title('WT: late - early', wrap = True, fontsize = 15)


# label data poitns




ax6.legend(loc='center left', bbox_to_anchor=(1, 0.80), fancybox=True, fontsize = 15);
fig.tight_layout()

#fig.savefig(f"output_files/DevPF_DE_volcano_FDR01_P01_FC1.png", dpi = 300,\
#                    bbox_inches = 'tight')

# %%
df2 = dfs[2]
df2
# Out:
#                    Gene Protein.ID  \
# 1304                T1F     Q27172
# 1305  GSPATT00036297001     A0C8P5
# 1306            PTIWI09     Q3SE53
# 1307  GSPATT00035387001     A0C641
# 1308  GSPATT00008359001     A0CM63
# ...                 ...        ...
# 1951  GSPATT00034354001     A0C260
# 1952  GSPATT00020767001     A0DVP7
# 1953           can-A4-1     Q3SDX2
# 1954  GSPATT00024473001     A0E8X5
# 1955  GSPATT00007548001     A0CH41
#
#                                     Protein.Description  \
# 1304                     Trichocyst matrix protein T1-F
# 1305  Chromosome undetermined scaffold_159, whole ge...
# 1306  Chromosome undetermined scaffold_66, whole gen...
# 1307  Chromosome undetermined scaffold_151, whole ge...
# 1308  Chromosome undetermined scaffold_21, whole gen...
# ...                                                 ...
# 1951                               Alanine--tRNA ligase
# 1952  Chromosome undetermined scaffold_66, whole gen...
# 1953               Serine/threonine-protein phosphatase
# 1954  Chromosome undetermined scaffold_83, whole gen...
# 1955  Chromosome undetermined scaffold_18, whole gen...
#
#                     Organism  found.in.files  \
# 1304  Paramecium tetraurelia               1
# 1305  Paramecium tetraurelia               1
# 1306  Paramecium tetraurelia               1
# 1307  Paramecium tetraurelia               1
# 1308  Paramecium tetraurelia               1
# ...                      ...             ...
# 1951  Paramecium tetraurelia               1
# 1952  Paramecium tetraurelia               1
# 1953  Paramecium tetraurelia               1
# 1954  Paramecium tetraurelia               1
# 1955  Paramecium tetraurelia               1
#
#       found.in.file_P2854_TMT16plex_5prc_protein.tsv  found.in.conditions  \
# 1304                                               1                    4
# 1305                                               1                    4
# 1306                                               1                    4
# 1307                                               1                    4
# 1308                                               1                    4
# ...                                              ...                  ...
# 1951                                               1                    4
# 1952                                               1                    4
# 1953                                               1                    4
# 1954                                               1                    4
# 1955                                               1                    4
#
#       found.in.reps  max.Unique.Peptides  max.Razor.Peptides  ...  \
# 1304              4                    0                   2  ...
# 1305              4                    0                   3  ...
# 1306              4                    1                  12  ...
# 1307              4                    2                   4  ...
# 1308              4                    0                   3  ...
# ...             ...                  ...                 ...  ...
# 1951              4                    0                  13  ...
# 1952              4                    4                   9  ...
# 1953              4                    0                   4  ...
# 1954              4                    2                   2  ...
# 1955              4                    0                   9  ...
#
#       qval.fdrtool  lfdr.fdrtool       comparison  hit_annotation_method  \
# 1304  1.358288e-13  1.358288e-13  PS17_L - PS17_E                  limma
# 1305  5.378482e-08  1.848932e-05  PS17_L - PS17_E                  limma
# 1306  6.198964e-06  5.530203e-05  PS17_L - PS17_E                  limma
# 1307  2.141059e-05  5.530203e-05  PS17_L - PS17_E                  limma
# 1308  2.748564e-05  5.530203e-05  PS17_L - PS17_E                  limma
# ...            ...           ...              ...                    ...
# 1951  9.378498e-01  1.000000e+00  PS17_L - PS17_E                  limma
# 1952  9.378703e-01  1.000000e+00  PS17_L - PS17_E                  limma
# 1953  9.379647e-01  1.000000e+00  PS17_L - PS17_E                  limma
# 1954  9.380352e-01  1.000000e+00  PS17_L - PS17_E                  limma
# 1955  9.380759e-01  1.000000e+00  PS17_L - PS17_E                  limma
#
#             pvalue       fdr    hit   hit_annotation  Total.Intensity  \
# 1304  1.779047e-07  0.000116   True     enriched hit          5452193
# 1305  1.747737e-06  0.000570   True     enriched hit          1430138
# 1306  7.724718e-06  0.001679   True     enriched hit          4415183
# 1307  1.332145e-05  0.001852   True     enriched hit        103369006
# 1308  1.563155e-05  0.001852   True     enriched hit          6673473
# ...            ...       ...    ...              ...              ...
# 1951  9.918374e-01  0.996827  False  enriched no hit          7782544
# 1952  9.922894e-01  0.996827  False  enriched no hit         25133406
# 1953  9.943681e-01  0.996827  False  enriched no hit          2245866
# 1954  9.959267e-01  0.996827  False  enriched no hit                0
# 1955  9.968265e-01  0.996827  False  enriched no hit         24111074
#
#       -log10(p)
# 1304   6.749813
# 1305   5.757524
# 1306   5.112117
# 1307   4.875448
# 1308   4.805998
# ...         ...
# 1951   0.003560
# 1952   0.003362
# 1953   0.002453
# 1954   0.001773
# 1955   0.001380
#
# [652 rows x 28 columns]

# %%
interest = []
interest_list = ['PTIWI09','GSPATT00001397001','GSPATT00025378001','GSPATT00009444001']

for df in dfs:
    inter = df.loc[df['Gene'].isin(interest_list)]
    inter = inter[['Gene','logFC','-log10(p)','hit_annotation']]
    interest.append(inter)

# %%
interest[2]
# Out:
#                    Gene     logFC  -log10(p)      hit_annotation
# 1306            PTIWI09 -1.345178   5.112117        enriched hit
# 1347  GSPATT00001397001  1.586669   2.262593           candidate
# 1349  GSPATT00025378001  1.600272   2.225870  enriched candidate
# 1541  GSPATT00009444001 -0.465824   0.637386     enriched no hit

# %%
# extract rows with enriched hits
enriched_hits = []
PTIWI19 = []
H_4 = []
H_2A = []
H_2B = []
DevPF12 = []

for df in dfs:
    e_hit = df.loc[df['hit_annotation'] == 'enriched hit']
    enriched_hits.append(e_hit)

for df in dfs:
    P19 = df.loc[df['Gene'] == 'PTIWI09']
    P19 = P19[['Gene','logFC','-log10(p)']]
    H4 = df.loc[df['Gene'] == 'GSPATT00001397001']
    H4 = H4[['Gene','logFC','-log10(p)']]
    H2A = df.loc[df['Gene'] == 'GSPATT00013999001']
    H2A = H2A[['Gene','logFC','-log10(p)']]
    H2B = df.loc[df['Gene'] == 'GSPATT00025378001']
    H2B = H2B[['Gene','logFC','-log10(p)']]
    D12 = df.loc[df['Gene'] == 'GSPATT00009444001']
    D12 = D12[['Gene','logFC','-log10(p)']]
    PTIWI19.append(P19)
    H_4.append(H4)
    H_2A.append(H2A)
    H_2B.append(H2B)
    DevPF12.append(D12)

# %%
enriched_hits[2]
# Out:
#                    Gene Protein.ID  \
# 1304                T1F     Q27172
# 1305  GSPATT00036297001     A0C8P5
# 1306            PTIWI09     Q3SE53
# 1307  GSPATT00035387001     A0C641
# 1308  GSPATT00008359001     A0CM63
# 1309  GSPATT00012163001     A0D0P4
# 1310  GSPATT00028551001     A0BG49
# 1311  GSPATT00036481001     A0CA84
# 1312              TMP2D     Q6BGI3
# 1313  GSPATT00034866001     A0C3M0
# 1314  GSPATT00010019001     A0CSI0
# 1315  GSPATT00031169001     A0BQX3
# 1316  GSPATT00025291001     A0EB90
# 1317  GSPATT00023786001     A0E6Z1
# 1318               KdB2     Q3SD85
# 1320  GSPATT00033212001     A0BXU2
# 1321  GSPATT00000536001     Q6BGJ9
# 1322  GSPATT00033210001     A0BXU0
# 1323  GSPATT00004039001     A0ED03
# 1327  GSPATT00000152001     A0BB00
# 1328  GSPATT00009875001     A0CS36
# 1330  GSPATT00020454001     A0DUR5
# 1331  GSPATT00008351001     A0CM55
# 1332  GSPATT00007520001     A0CH13
# 1333  GSPATT00017907001     A0DKL0
#
#                                     Protein.Description  \
# 1304                     Trichocyst matrix protein T1-F
# 1305  Chromosome undetermined scaffold_159, whole ge...
# 1306  Chromosome undetermined scaffold_66, whole gen...
# 1307  Chromosome undetermined scaffold_151, whole ge...
# 1308  Chromosome undetermined scaffold_21, whole gen...
# 1309                       pyruvate, phosphate dikinase
# 1310  Chromosome undetermined scaffold_105, whole ge...
# 1311  Chromosome undetermined scaffold_160, whole ge...
# 1312  Chromosome undetermined scaffold_1, whole geno...
# 1313  Chromosome undetermined scaffold_147, whole ge...
# 1314  Chromosome undetermined scaffold_26, whole gen...
# 1315  Chromosome undetermined scaffold_121, whole ge...
# 1316  Chromosome undetermined scaffold_87, whole gen...
# 1317  Chromosome undetermined scaffold_80, whole gen...
# 1318  Chromosome undetermined scaffold_20, whole gen...
# 1320  Chromosome undetermined scaffold_135, whole ge...
# 1321  Chromosome undetermined scaffold_1, whole geno...
# 1322                                 DNA 3'-5' helicase
# 1323  Chromosome undetermined scaffold_9, whole geno...
# 1327  Chromosome undetermined scaffold_1, whole geno...
# 1328  Chromosome undetermined scaffold_26, whole gen...
# 1330  Chromosome undetermined scaffold_64, whole gen...
# 1331  Chromosome undetermined scaffold_21, whole gen...
# 1332  Chromosome undetermined scaffold_18, whole gen...
# 1333  Chromosome undetermined scaffold_54, whole gen...
#
#                     Organism  found.in.files  \
# 1304  Paramecium tetraurelia               1
# 1305  Paramecium tetraurelia               1
# 1306  Paramecium tetraurelia               1
# 1307  Paramecium tetraurelia               1
# 1308  Paramecium tetraurelia               1
# 1309  Paramecium tetraurelia               1
# 1310  Paramecium tetraurelia               1
# 1311  Paramecium tetraurelia               1
# 1312  Paramecium tetraurelia               1
# 1313  Paramecium tetraurelia               1
# 1314  Paramecium tetraurelia               1
# 1315  Paramecium tetraurelia               1
# 1316  Paramecium tetraurelia               1
# 1317  Paramecium tetraurelia               1
# 1318  Paramecium tetraurelia               1
# 1320  Paramecium tetraurelia               1
# 1321  Paramecium tetraurelia               1
# 1322  Paramecium tetraurelia               1
# 1323  Paramecium tetraurelia               1
# 1327  Paramecium tetraurelia               1
# 1328  Paramecium tetraurelia               1
# 1330  Paramecium tetraurelia               1
# 1331  Paramecium tetraurelia               1
# 1332  Paramecium tetraurelia               1
# 1333  Paramecium tetraurelia               1
#
#       found.in.file_P2854_TMT16plex_5prc_protein.tsv  found.in.conditions  \
# 1304                                               1                    4
# 1305                                               1                    4
# 1306                                               1                    4
# 1307                                               1                    4
# 1308                                               1                    4
# 1309                                               1                    4
# 1310                                               1                    4
# 1311                                               1                    4
# 1312                                               1                    4
# 1313                                               1                    4
# 1314                                               1                    4
# 1315                                               1                    4
# 1316                                               1                    4
# 1317                                               1                    4
# 1318                                               1                    4
# 1320                                               1                    4
# 1321                                               1                    4
# 1322                                               1                    4
# 1323                                               1                    4
# 1327                                               1                    4
# 1328                                               1                    4
# 1330                                               1                    4
# 1331                                               1                    4
# 1332                                               1                    4
# 1333                                               1                    4
#
#       found.in.reps  max.Unique.Peptides  max.Razor.Peptides  ...  \
# 1304              4                    0                   2  ...
# 1305              4                    0                   3  ...
# 1306              4                    1                  12  ...
# 1307              4                    2                   4  ...
# 1308              4                    0                   3  ...
# 1309              4                    7                  30  ...
# 1310              4                    0                  11  ...
# 1311              4                    1                   2  ...
# 1312              4                    0                   8  ...
# 1313              4                    3                   5  ...
# 1314              4                    2                   5  ...
# 1315              4                    0                   3  ...
# 1316              4                    2                   9  ...
# 1317              4                    4                   4  ...
# 1318              4                    8                   8  ...
# 1320              4                    2                   2  ...
# 1321              4                    3                   6  ...
# 1322              4                    7                   8  ...
# 1323              4                    3                   4  ...
# 1327              4                    0                   2  ...
# 1328              4                    0                   2  ...
# 1330              4                    0                   3  ...
# 1331              4                    0                   7  ...
# 1332              4                    0                   2  ...
# 1333              4                    0                   3  ...
#
#       qval.fdrtool  lfdr.fdrtool       comparison  hit_annotation_method  \
# 1304  1.358288e-13  1.358288e-13  PS17_L - PS17_E                  limma
# 1305  5.378482e-08  1.848932e-05  PS17_L - PS17_E                  limma
# 1306  6.198964e-06  5.530203e-05  PS17_L - PS17_E                  limma
# 1307  2.141059e-05  5.530203e-05  PS17_L - PS17_E                  limma
# 1308  2.748564e-05  5.530203e-05  PS17_L - PS17_E                  limma
# 1309  3.075050e-05  1.333498e-04  PS17_L - PS17_E                  limma
# 1310  5.155203e-05  1.333498e-04  PS17_L - PS17_E                  limma
# 1311  5.640032e-05  6.837947e-04  PS17_L - PS17_E                  limma
# 1312  1.433887e-04  6.837947e-04  PS17_L - PS17_E                  limma
# 1313  2.440469e-04  6.837947e-04  PS17_L - PS17_E                  limma
# 1314  2.539744e-04  6.837947e-04  PS17_L - PS17_E                  limma
# 1315  2.655318e-04  6.492861e-03  PS17_L - PS17_E                  limma
# 1316  9.420556e-04  6.492861e-03  PS17_L - PS17_E                  limma
# 1317  1.640430e-03  6.492861e-03  PS17_L - PS17_E                  limma
# 1318  1.774765e-03  6.492861e-03  PS17_L - PS17_E                  limma
# 1320  3.831996e-03  2.089483e-02  PS17_L - PS17_E                  limma
# 1321  4.744148e-03  2.089483e-02  PS17_L - PS17_E                  limma
# 1322  5.382234e-03  2.089483e-02  PS17_L - PS17_E                  limma
# 1323  5.940542e-03  2.089483e-02  PS17_L - PS17_E                  limma
# 1327  1.523038e-02  8.526163e-02  PS17_L - PS17_E                  limma
# 1328  1.816361e-02  8.526163e-02  PS17_L - PS17_E                  limma
# 1330  2.198363e-02  8.526163e-02  PS17_L - PS17_E                  limma
# 1331  2.378916e-02  1.861117e-01  PS17_L - PS17_E                  limma
# 1332  2.938649e-02  2.887226e-01  PS17_L - PS17_E                  limma
# 1333  4.161476e-02  2.887226e-01  PS17_L - PS17_E                  limma
#
#             pvalue       fdr   hit  hit_annotation  Total.Intensity  -log10(p)
# 1304  1.779047e-07  0.000116  True    enriched hit          5452193   6.749813
# 1305  1.747737e-06  0.000570  True    enriched hit          1430138   5.757524
# 1306  7.724718e-06  0.001679  True    enriched hit          4415183   5.112117
# 1307  1.332145e-05  0.001852  True    enriched hit        103369006   4.875448
# 1308  1.563155e-05  0.001852  True    enriched hit          6673473   4.805998
# 1309  1.704205e-05  0.001852  True    enriched hit         49675232   4.768478
# 1310  2.251613e-05  0.002097  True    enriched hit         20082218   4.647506
# 1311  8.667950e-05  0.004710  True    enriched hit           627662   4.062084
# 1312  3.676519e-05  0.002996  True    enriched hit          2921962   4.434563
# 1313  5.022963e-05  0.003157  True    enriched hit          4116972   4.299040
# 1314  5.161557e-05  0.003157  True    enriched hit          9023302   4.287219
# 1315  5.325598e-05  0.003157  True    enriched hit          1216574   4.273632
# 1316  1.003306e-04  0.005032  True    enriched hit          6534159   3.998566
# 1317  1.885137e-04  0.007682  True    enriched hit          7844160   3.724657
# 1318  1.488838e-04  0.006594  True    enriched hit          6489336   3.827152
# 1320  3.096590e-04  0.010626  True    enriched hit          1675723   3.509116
# 1321  2.769879e-04  0.010623  True    enriched hit          1350908   3.557539
# 1322  3.043143e-04  0.010626  True    enriched hit          5160338   3.516678
# 1323  3.288279e-04  0.010720  True    enriched hit          9310548   3.483031
# 1327  6.508158e-04  0.017680  True    enriched hit           733465   3.186542
# 1328  7.493293e-04  0.019543  True    enriched hit         24364101   3.125327
# 1330  8.831281e-04  0.021326  True    enriched hit          3184907   3.053976
# 1331  9.493294e-04  0.022106  True    enriched hit         24785915   3.022583
# 1332  1.123026e-03  0.025249  True    enriched hit          2499247   2.949610
# 1333  1.484634e-03  0.032266  True    enriched hit          3440302   2.828380
#
# [25 rows x 28 columns]
